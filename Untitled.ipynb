# %% [markdown]
# +------+------+
# | Data | Next |
# +------+------+
#
#
#
# Head
#  ↓
# [10|•] → [20|•] → [30|NULL]

# %%
class Node:
    def __init__(self, data):
        
        self.data = data
        self.next = None
head = Node(10)
print(f"Address of the head node: {head}, Data: {head.data}")
head.next = Node(20) # this is for second node value 
print(head.next.data)
print( f" address of the next node {head.next},data: {head.next.data}")
# Out:
# Address of the head node: <__main__.Node object at 0x108295fd0>, Data: 10
# 20
#  address of the next node <__main__.Node object at 0x1082dd450>,data: 20

# %%
head.next.next = Node(30)

# %%
print(head.next.next.data)
# Out:
# 30

# %%
head.next.next.next = Node(40)

# %%
print(head.next.next.next.data)
# Out:
# 40

# %%
temp = head
while temp is not No
